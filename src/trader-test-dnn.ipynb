# %%
import os
os.environ['F_ENABLE_ONEDNN_OPTS'] = '0'

# %%
import plotly

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use("seaborn")
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
import strategy
inst = strategy.AlgoStrategy('BTC_USD')
# Out:
# 2022-08-19 15:07:10.647167: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/p/anaconda3/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
inst.download_data()
# Out:
# /home/p/code/cybersquirrel/src

# %%
inst.add_features()

# %%
inst.plot_features()

# %%
inst.data
# Out:
#                            open        high         low       close  volume  \
# datetime
# 2021-01-05 14:45:00 31998.10000 32438.50000 31861.30000 32394.90000    7847
# 2021-01-05 15:00:00 32395.40000 32414.70000 32059.70000 32111.50000    6642
# 2021-01-05 15:15:00 32112.00000 32350.90000 32105.70000 32193.40000    7325
# 2021-01-05 15:30:00 32192.40000 32196.20000 31962.00000 32005.60000    7191
# 2021-01-05 15:45:00 32006.50000 32206.70000 31991.90000 32186.70000    5495
# ...                         ...         ...         ...         ...     ...
# 2021-12-30 23:00:00 47098.30000 47222.80000 46995.80000 47117.60000   22154
# 2021-12-30 23:15:00 47116.90000 47261.20000 47046.20000 47132.00000   19715
# 2021-12-30 23:30:00 47130.10000 47171.40000 46941.00000 47098.50000   18715
# 2021-12-30 23:45:00 47097.80000 47186.20000 47053.90000 47124.60000   20094
# 2021-12-31 00:00:00 47127.70000 47414.10000 47086.40000 47301.30000   22465
#
# ...

# %%
inst.train_and_save()
# Out:
# 2022-08-19 15:07:52.079076: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-08-19 15:07:52.079165: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (brombeere): /proc/driver/nvidia/version does not exist
# 2022-08-19 15:07:52.080738: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# 256/256 [==============================] - 0s 1ms/step
# /home/p/code/cybersquirrel/src
# INFO:tensorflow:Assets written to: /home/p/code/cybersquirrel/src/../data/BTC_USD_M15_DNN_model/assets
# /home/p/code/cybersquirrel/src

# %%
inst.plot_test()

# %%
inst.test
# Out:
#                                 open       high        low      close  volume  \
# datetime
# 2021-08-31 08:00:00+00:00 4540.00000 4541.00000 4539.00000 4539.10000     861
# 2021-08-31 08:30:00+00:00 4538.80000 4539.50000 4537.80000 4538.50000     889
# 2021-08-31 09:00:00+00:00 4538.50000 4539.80000 4537.50000 4538.10000    1108
# 2021-08-31 09:30:00+00:00 4538.20000 4538.30000 4535.50000 4535.90000     759
# 2021-08-31 10:00:00+00:00 4536.00000 4537.00000 4533.00000 4534.70000     830
# ...                              ...        ...        ...        ...     ...
# 2021-12-30 20:30:00+00:00 4798.20000 4799.20000 4780.00000 4784.80000    3693
# 2021-12-30 21:00:00+00:00 4784.60000 4787.50000 4781.70000 4785.00000     812
# 2021-12-30 21:30:00+00:00 4784.70000 4786.00000 4783.40000 4784.70000     201
# 2021-12-30 23:00:00+00:00 4786.90000 4787.80000 4785.50000 4786.30000     423
# 2021-12-30 23:30:00+00:00 4786.00000 4786.50000 4783.50000 4785.30000     285
#
# ...
